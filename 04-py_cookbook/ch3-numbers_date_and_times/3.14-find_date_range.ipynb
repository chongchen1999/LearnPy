# %%
from datetime import datetime, date, timedelta
import calendar

def get_month_range(start_date=None):
    if start_date is None:
        start_date = date.today().replace(day=1)
    _, days_in_month = calendar.monthrange(start_date.year, start_date.month)
    end_date = start_date + timedelta(days=days_in_month)
    return (start_date, end_date)

def date_range(start, stop, step):
    while start < stop:
        yield start
        start += step

# Example 1: Looping over each day in the current month
a_day = timedelta(days=1)
first_day, last_day = get_month_range()
while first_day < last_day:
    print(first_day)
    first_day += a_day

# Example 2: Using the date_range generator to loop over dates with a custom step
for d in date_range(datetime(2023, 10, 1), datetime(2023, 11, 1), timedelta(hours=6)):
    print(d)
# Out:
# 2025-01-01
# 2025-01-02
# 2025-01-03
# 2025-01-04
# 2025-01-05
# 2025-01-06
# 2025-01-07
# 2025-01-08
# 2025-01-09
# 2025-01-10
# 2025-01-11
# 2025-01-12
# 2025-01-13
# 2025-01-14
# 2025-01-15
# 2025-01-16
# 2025-01-17
# 2025-01-18
# 2025-01-19
# 2025-01-20
# 2025-01-21
# 2025-01-22
# 2025-01-23
# 2025-01-24
# 2025-01-25
# 2025-01-26
# 2025-01-27
# 2025-01-28
# 2025-01-29
# 2025-01-30
# 2025-01-31
# 2023-10-01 00:00:00
# 2023-10-01 06:00:00
# 2023-10-01 12:00:00
# 2023-10-01 18:00:00
# 2023-10-02 00:00:00
# 2023-10-02 06:00:00
# 2023-10-02 12:00:00
# 2023-10-02 18:00:00
# 2023-10-03 00:00:00
# 2023-10-03 06:00:00
# 2023-10-03 12:00:00
# 2023-10-03 18:00:00
# 2023-10-04 00:00:00
# 2023-10-04 06:00:00
# 2023-10-04 12:00:00
# 2023-10-04 18:00:00
# 2023-10-05 00:00:00
# 2023-10-05 06:00:00
# 2023-10-05 12:00:00
# 2023-10-05 18:00:00
# 2023-10-06 00:00:00
# 2023-10-06 06:00:00
# 2023-10-06 12:00:00
# 2023-10-06 18:00:00
# 2023-10-07 00:00:00
# 2023-10-07 06:00:00
# 2023-10-07 12:00:00
# ...
